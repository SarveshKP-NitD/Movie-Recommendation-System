# %% [markdown]
# # Data Preprocessing
#
# In this notebook, we prepare the MovieLens 100K dataset for building recommendation models.
#
# The preprocessing pipeline includes:
#
# - Loading processed datasets
# - Data validation
# - User and Movie ID encoding
# - Train-Test Split
# - Interaction Matrix Creation
# - Preparing data for recommendation algorithms

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split

import warnings
warnings.filterwarnings("ignore")

print("Libraries Loaded Successfully")
# Out:
# Libraries Loaded Successfully

# %%
ratings = pd.read_csv(
    "../data/ml-100k/u.data",
    sep="\t",
    names=["user_id", "movie_id", "rating", "timestamp"]
)

movies = pd.read_csv(
    "../data/ml-100k/u.item",
    sep="|",
    encoding="latin-1",
    header=None,
    usecols=[0,1],
    names=["movie_id","movie_title"]
)

movie_ratings = pd.merge(
    ratings,
    movies,
    on="movie_id"
)

movie_ratings.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 ratings = pd.read_csv(
#       2     "../data/ml-100k/u.data",
#       3     sep="\t",
#       4     names=["user_id", "movie_id", "rating", "timestamp"]
#       5 )
#       7 movies = pd.read_csv(
#       8     "../data/ml-100k/u.item",
#       9     sep="|",
#    (...)     13     names=["movie_id","movie_title"]
#      14 )
#      16 movie_ratings = pd.merge(
#      17     ratings,
#      18     movies,
#      19     on="movie_id"
#      20 )
#
# ...

# %%
import os

print("Current Working Directory:")
print(os.getcwd())
# Out:
# Current Working Directory:
# /home/guest/Desktop/sarvesh

# %%
print(os.listdir())
# Out:
# ['UCI_HAR_Activity_Wise_Results.csv', 'Yolov11.zip', 'FL_CIFAR10.ipynb', 'data', 'MNIST_AlexNet_Baseline_vs_PQSU.csv', '01_Data_Loading_and_EDA.ipynb', 'KTH_Final_Report.xlsx', 'species_experiment_results.csv', 'final_model_85_83.pth', 'best_densenet121_20ep.pth', 'Untitled.ipynb', 'Untitled2.ipynb', 'Potholes_dataset.zip', 'unet_epoch10.keras', 'disease_confusion_matrix.png', 'ml-100k', 'MO_94.zip', '__MACOSX', 'Mushroom Species.ipynb', 'best_densenet121_species.pth', 'KTH_pqsu_metrics_formatted.csv', 'MNIST_AlexNet_FL_PQSU_Final_Complete_Results.csv', 'best_resnet50_species_20ep.pth', 'species_results.csv', 'species_classification_report.txt', 'project', 'Ablation_Study_Results.csv', 'unet_epoch10_backup.keras', 'best_mobilenetv3_10ep.pth', 'allbut.pl', 'mk18', 'best_species_model_20ep.pth', 'PQSU_Ablation_Study_Full.csv', 'UCI HAR Dataset', 'Agaricus augustus_1_brightness.jpg', 'pothole_ai', 'best_kth_pqsu.pth', 'Untitled Folder', 'UCI_HAR_PQSU_Final_Results.csv', 'bdd100k.zip', '
# ...

# %%
ratings = pd.read_csv(
    "ml-100k/u.data",
    sep="\t",
    names=["user_id", "movie_id", "rating", "timestamp"]
)

movies = pd.read_csv(
    "ml-100k/u.item",
    sep="|",
    encoding="latin-1",
    header=None,
    usecols=[0, 1],
    names=["movie_id", "movie_title"]
)

movie_ratings = pd.merge(
    ratings,
    movies,
    on="movie_id"
)

movie_ratings.head()
# Out:
#    user_id  movie_id  rating  timestamp                 movie_title
# 0      196       242       3  881250949                Kolya (1996)
# 1      186       302       3  891717742    L.A. Confidential (1997)
# 2       22       377       1  878887116         Heavyweights (1994)
# 3      244        51       2  880606923  Legends of the Fall (1994)
# 4      166       346       1  886397596         Jackie Brown (1997)
